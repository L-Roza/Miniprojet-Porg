# %% [markdown]
# <a href="https://colab.research.google.com/github/L-Roza/Miniprojet-Porg/blob/main/Lab1_semaine1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Objectif: Construire un index inversé

# %%
# Construire la collection
# une collection est un ensemble de documents identifiés par une clé ou un identifiant
d0 = "In summer, the sun shines and the temperature rises."
d1 = "In winter, snow falls and the temperature decreases."
d2 = "The sun melts the snow."
d3 = "In the mountains, snow sometimes falls in summer."

collection ={"doc0":d0, "doc1":d1, "doc2":d2, "doc3":d3}

collection
# Out:
# {'doc0': 'In summer, the sun shines and the temperature rises.',
#  'doc1': 'In winter, snow falls and the temperature decreases.',
#  'doc2': 'The sun melts the snow.',
#  'doc3': 'In the mountains, snow sometimes falls in summer.'}
